# %%
import pandas as pd
from random import seed
from random import randrange
from math import exp
from math import log
from math import floor
import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
shape1=[10, 50,100, 200, 350, 500]

# %%
shape11=[1000, 3000, 8000, 10000, 15000, 19999]

# %%
#SVM implementing from scratch

# %%
ex_timeSW=[13.242623000000037,
 40.20173,
 104.86266400000005,
 132.37144899999998,
 226.599148,
 343.5494739999999]

# %%
ex_timeSP=[4.21449900000016,
 12.652153999999882,
 32.96289500000012,
 40.59098300000005,
 60.97192900000027,
 82.57219399999985]

# %%
fig, ax = plt.subplots()
ax.plot(shape1, ex_timeSW, '-b', label='Without PCA')
ax.plot(shape1, ex_timeSP, '--r', label='With PCA')
plt.xlabel('Dataset(Mb)')
plt.ylabel('Execution_Time (seconds)')
plt.title('SVM from scratch on conventional system')
leg = ax.legend();

# %%
accSW=[95.59999999999998,
 96.06666666666668,
 55.93749999999999,
 56.199999999999996,
 54.78000000000001,
 49.49999999999999]

# %%
accSP=[81.80000000000001,
 87.93333333333334,
 39.95,
 60.06,
 48.88666666666667,
 49.29500000000001]

# %%
fig, ax = plt.subplots()
ax.plot(shape1, accSW, '-b', label='Without PCA')
ax.plot(shape1, accSP, '--r', label='With PCA')
plt.xlabel('Dataset(Mb)')
plt.ylabel('Accuracy(%)')
plt.title('SVM from scratch on conventional system')
leg = ax.legend();

# %%
#svm from built in library

# %%
ex_timeIW=[0.12482600000021193,
 0.6587680000002365,
 145.8310260000003,
 232.8160310000003,
 468.73988899999995,
 712.5270609999998]

# %%
ex_timeIP=[0.15650400000004083,
 1.8367440000001807,
 147.44636900000023,
 202.8126569999995,
 337.15781400000014,
 529.012514]

# %%
fig, ax = plt.subplots()
ax.plot(shape1, ex_timeIW, '-b', label='Without PCA')
ax.plot(shape1, ex_timeIP, '--r', label='With PCA')
plt.xlabel('Dataset(Mb)')
plt.ylabel('Execution_Time (seconds)')
plt.title('SVM using built in library on conventional system')
leg = ax.legend();

# %%
accIW=[0.91, 0.9216666666666666, 0.67125, 0.624, 0.5786666666666667, 0.5475]
accIP=[0.795, 0.9066666666666666, 0.648125, 0.599, 0.5803333333333334, 0.5515]

# %%
fig, ax = plt.subplots()
ax.plot(shape1, accIW, '-b', label='Without PCA')
ax.plot(shape1, accIP, '--r', label='With PCA')
plt.xlabel('Dataset(Mb)')
plt.ylabel('Accuracy(%)')
plt.title('SVM using built in library on conventional system')
leg = ax.legend();

# %%
#SVM implementation on distributed system

# %%
ex_timeDW=[5.054363000000194,
 5.243217000000186,
 5.89610999999968,
 6.176398000000518,
 7.202565000000504,
 7.881464000000051]

ex_timeDP=[4.0596650000006775,
 5.364376999999877,
 5.721912999999404,
 5.75171599999976,
 6.101326999999401,
 6.7581239999999525]

# %%
fig, ax = plt.subplots()
ax.plot(shape1, ex_timeDW, '-b', label='Without PCA')
ax.plot(shape1, ex_timeDP, '--r', label='With PCA')
plt.xlabel('Dataset(Mb)')
plt.ylabel('Execution_Time (seconds)')
plt.title('SVM using map-reduce')
leg = ax.legend();

# %%
accDW=[47.400000000000006,
 49.93333333333333,
 50.91250000000001,
 50.66,
 50.026666666666664,
 50.575]

accDP=[47.400000000000006,
 49.93333333333333,
 50.91250000000001,
 50.66,
 50.026666666666664,
 50.575]

# %%
fig, ax = plt.subplots()
ax.plot(shape1, accDW, '-b', label='Without PCA')
ax.plot(shape1, accDP, '--r', label='With PCA')
plt.xlabel('Dataset(Mb)')
plt.ylabel('Accuracy(%)')
plt.title('SVM using map reduce on distributed system')
leg = ax.legend();

# %%
fig, ax = plt.subplots()
ax.plot(shape1, ex_timeSW, '-b', label='scratch')
ax.plot(shape1, ex_timeIW, '-r', label='built in library')
ax.plot(shape1, ex_timeDW, '-g', label='map-reduce')
plt.xlabel('Dataset(Mb)')
plt.ylabel('Execution_Time (seconds)')
plt.title('SVM implementation without pca')
leg = ax.legend();

# %%
fig, ax = plt.subplots()
ax.plot(shape1, ex_timeSP, '-b', label='scratch')
ax.plot(shape1, ex_timeIP, '-r', label='built in library')
ax.plot(shape1, ex_timeDP, '-g', label='map-reduce')
plt.xlabel('Dataset(Mb)')
plt.ylabel('Execution_Time (seconds)')
plt.title('SVM implementation with pca')
leg = ax.legend();

# %%
#fig, ax = plt.subplots()
#ax.plot(shape1, accSW, '-b', label='scratch')
#ax.plot(shape1, accIW, '-r', label='built in library')
#ax.plot(shape1, accDW, '-g', label='map-reduce')
#plt.xlabel('Dataset(Kb)')
#plt.ylabel('Accuracy(%)')
#plt.title('SVM implementation without pca')
#leg = ax.legend();

# %%
#fig, ax = plt.subplots()
#ax.plot(shape1, accSP, '-b', label='scratch')
#ax.plot(shape1, accIP, '-r', label='built in library')
#ax.plot(shape1, accDP, '-g', label='map-reduce')
#plt.xlabel('Dataset(Kb)')
#plt.ylabel('Accuracy(%)')
#plt.title('SVM implementation with pca')
#leg = ax.legend();
